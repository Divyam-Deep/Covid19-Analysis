# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyam-Deep/Covid19-Analysis/blob/main/Covid_19_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/Covid_19_data.csv')
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.shape
# Out:
# (321, 6)

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
data.dtypes
# Out:
# Date         object
# State        object
# Region       object
# Confirmed     int64
# Deaths        int64
# Recovered     int64
# dtype: object

# %%
data.State.fillna('Not Mentioned', inplace = True)

# %%
data.isnull().sum()
# Out:
# Date         0
# State        0
# Region       0
# Confirmed    0
# Deaths       0
# Recovered    0
# dtype: int64

# %%
data.head(2)
# Out:
#         Date          State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020  Not Mentioned  Afghanistan       1939      60        252
# 1  4/29/2020  Not Mentioned      Albania        766      30        455

# %%
data.groupby('Region').sum()
# Out:
#                          Date          State  Confirmed  Deaths  Recovered
# Region
# Afghanistan         4/29/2020  Not Mentioned       1939      60        252
# Albania             4/29/2020  Not Mentioned        766      30        455
# Algeria             4/29/2020  Not Mentioned       3848     444       1702
# Andorra             4/29/2020  Not Mentioned        743      42        423
# Angola              4/29/2020  Not Mentioned         27       2          7
# ...                       ...            ...        ...     ...        ...
# West Bank and Gaza  4/29/2020  Not Mentioned        344       2         71
# Western Sahara      4/29/2020  Not Mentioned          6       0          5
# Yemen               4/29/2020  Not Mentioned          6       0          1
# Zambia              4/29/2020  Not Mentioned         97       3         54
# Zimbabwe            4/29/2020  Not Mentioned         32       4          5
#
# [187 rows x 5 columns]

# %%
data.groupby('Region')[['Confirmed', 'Deaths', 'Recovered']].sum().sort_values(by = 'Deaths' , ascending = False)
# Out:
#              Confirmed  Deaths  Recovered
# Region
# US             1039909   60967     120720
# Italy           203591   27682      71252
# UK              166441   26166        857
# Spain           236899   24275     132929
# France          166543   24121      49118
# ...                ...     ...        ...
# Holy See            10       0          2
# Grenada             20       0         13
# South Sudan         34       0          0
# Nepal               57       0         16
# Laos                19       0          7
#
# [187 rows x 3 columns]

# %%
data = data[~(data.Confirmed < 10)]

# %%
data.shape
# Out:
# (304, 6)

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(1)
# Out:
# Region
# US    1039909
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = True)
# Out:
# Region
# Cambodia                        0
# Seychelles                      0
# Saint Lucia                     0
# Central African Republic        0
# Saint Kitts and Nevis           0
#                             ...
# France                      24121
# Spain                       24275
# UK                          26165
# Italy                       27682
# US                          60967
# Name: Deaths, Length: 180, dtype: int64

# %%
data[data.Region == 'India']
# Out:
#          Date          State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020  Not Mentioned  India      33062    1079       8437

# %%
data.sort_values(by = 'Confirmed' , ascending = True)
# Out:
#           Date          State    Region  Confirmed  Deaths  Recovered
# 156  4/29/2020  Not Mentioned  Suriname         10       1          8
# 70   4/29/2020  Not Mentioned  Holy See         10       0          2
# 59   4/29/2020  Not Mentioned    Gambia         10       1          8
# 318  4/29/2020          Yukon    Canada         11       0          0
# 217  4/29/2020      Greenland   Denmark         11       0         11
# ..         ...            ...       ...        ...     ...        ...
# 57   4/29/2020  Not Mentioned    France     165093   24087      48228
# 168  4/29/2020  Not Mentioned        UK     165221   26097          0
# 80   4/29/2020  Not Mentioned     Italy     203591   27682      71252
# 153  4/29/2020  Not Mentioned     Spain     236899   24275     132929
# 265  4/29/2020       New York        US     299691   23477          0
#
# [304 rows x 6 columns]

# %%
data.sort_values(by = 'Recovered' , ascending = False)
# Out:
#           Date          State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020  Not Mentioned           Spain     236899   24275     132929
# 61   4/29/2020  Not Mentioned         Germany     161539    6467     120400
# 76   4/29/2020  Not Mentioned            Iran      93657    5957      73791
# 80   4/29/2020  Not Mentioned           Italy     203591   27682      71252
# 229  4/29/2020          Hubei  Mainland China      68128    4512      63616
# ..         ...            ...             ...        ...     ...        ...
# 258  4/29/2020         Nevada              US       4934     230          0
# 257  4/29/2020       Nebraska              US       3851      56          0
# 255  4/29/2020        Montana              US        451      16          0
# 254  4/29/2020       Missouri              US       7660     338          0
# 274  4/29/2020           Ohio              US      17303     937          0
#
# [304 rows x 6 columns]
